# %%
import cdflib

# %%
let1 = cdflib.CDF(r'/home/annafed/Documents/GitHub/epd_plot-main/solo_loader-main-shift/data/l2/epd/step/solo_L2_epd-step-main_20211028_V01.cdf')

# %%
o = let1.cdf_info()

# %%
o
# Out:
# {'CDF': PosixPath('/tmp/tmpqg_kgx47.cdf'),
#  'Version': '3.7.1',
#  'Encoding': 6,
#  'Majority': 'Row_major',
#  'rVariables': [],
#  'zVariables': ['EPOCH',
#   'DELTA_EPOCH',
#   'QUALITY_FLAG',
#   'QUALITY_BITMASK',
#   'SMALL_PIXELS_FLAG',
#   'Integral_01_Flux',
#   'Integral_01_Uncertainty',
#   'Integral_01_Rate',
#   'Integral_02_Flux',
#   'Integral_02_Uncertainty',
#   'Integral_02_Rate',
#   'Integral_03_Flux',
#   'Integral_03_Uncertainty',
#   'Integral_03_Rate',
#   'Integral_04_Flux',
#   'Integral_04_Uncertainty',
#   'Integral_04_Rate',
#   'Integral_05_Flux',
#   'Integral_05_Uncertainty',
#   'Integral_05_Rate',
#   'Integral_06_Flux',
#   'Integral_06_Uncertainty',
#   'Integral_06_Rate',
#   'Integral_07_Flux',
#   'Integral_07_Uncertainty',
#   'Integral_07_Rate',
#   'Integral_08_Flux',
#   'Integral_08_Uncertainty',
#   'Integral_08_Rate',
#   'Integral_09_Flux',
#   'Integral_09_Uncertainty',
#   'Integral_09_Rate',
#   'Integral_10_Flux',
# ...

# %%
let1.varinq('Electron_Avg_Flux_Mult')
# Out:
# {'Variable': 'Electron_Avg_Flux_Mult',
#  'Num': 119,
#  'Var_Type': 'zVariable',
#  'Data_Type': 21,
#  'Data_Type_Description': 'CDF_REAL4',
#  'Num_Elements': 1,
#  'Num_Dims': 1,
#  'Dim_Sizes': [32],
#  'Sparse': 'No_sparse',
#  'Last_Rec': 0,
#  'Rec_Vary': False,
#  'Dim_Vary': [-1],
#  'Pad': array([-1.e+30], dtype=float32),
#  'Compress': 0,
#  'Block_Factor': 0}

# %%
let1.varget('Electron_Avg_Flux_Mult')
# Out:
# array([0.60327756, 0.61609703, 0.6824617 , 0.78513914, 1.1724892 ,
#        1.350095  , 1.3473226 , 1.3506883 , 1.3493143 , 1.3455917 ,
#        1.331373  , 1.3592242 , 1.3661284 , 1.3310052 , 1.2871879 ,
#        1.2019504 , 1.1570297 , 1.1499548 , 1.1567578 , 1.1638381 ,
#        1.1640719 , 1.1668255 , 1.1626223 , 1.1711454 , 1.1608912 ,
#        1.1653233 , 1.1591299 , 1.1649846 , 1.174924  , 1.1669562 ,
#        1.1751835 , 1.1798428 ], dtype=float32)

# %%
a = let1.varget('Electron_01_Flux_Mult')
print(len(a))
# Out:
# 32

# %%
info = let1.cdf_info()
zVar = info.get('zVariables')
for i in zVar:
    print(i," : ",let1.varattsget(i),'\n')
# Out:
# EPOCH  :  {'FIELDNAM': 'Epoch', 'CATDESC': 'Nanoseconds since J2000', 'FILLVAL': -9223372036854775808, 'LABLAXIS': 'Time', 'UNITS': 'nanoseconds', 'VALIDMIN': -43135816000000, 'VALIDMAX': 1577880069184000000, 'SCALEMIN': 688651269184000000, 'SCALEMAX': 688737669184000000, 'VAR_TYPE': 'support_data', 'SCALETYP': 'linear', 'VAR_NOTES': 'Start of acquisition interval. Variable cadence: 10 s in far mode, 1 s in close mode\n', 'DELTA_PLUS_VAR': 'DELTA_EPOCH', 'CADENCE': '1 second, 10 seconds'}
#
# DELTA_EPOCH  :  {'FIELDNAM': 'Delta epoch', 'CATDESC': 'Accumulation period in seconds', 'FILLVAL': 4294967295, 'LABLAXIS': 'Delta epoch', 'UNITS': 'seconds', 'VALIDMIN': 0, 'VALIDMAX': 3600, 'SCALEMIN': 0, 'SCALEMAX': 3600, 'VAR_TYPE': 'support_data', 'SCALETYP': 'linear', 'VAR_NOTES': ' ', 'DEPEND_0': 'EPOCH', 'FORMAT': 'I'}
#
# ...
